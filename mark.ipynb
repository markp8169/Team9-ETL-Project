# %%
#Dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
#Reading in the csv files

#Creates two variables containing the locations of each csv
csvpath1 = "csvFiles/healthInspections.csv"
csvpath2 = "csvFiles/healthViolations.csv"

#Translates the csv files into pandas dataframes
csvHealthInspections = pd.read_csv(csvpath1)
csvHealthViolations = pd.read_csv(csvpath2)

# %%
csvHealthInspections.head()
# Out:
#   serial_number        activity_date        facility_name  score grade  \
# 0     DAJ00E07B  2017-12-29T00:00:00  HABITAT COFFEE SHOP     95     A
# 1     DAQOKRFZB  2017-12-29T00:00:00             REILLY'S     92     A
# 2     DASJI4LUR  2017-12-29T00:00:00       STREET CHURROS     93     A
# 3     DAWVA0CY3  2017-12-29T00:00:00  RIO GENTLEMANS CLUB     93     A
# 4     DAKFCHD0L  2017-12-29T00:00:00    LE PAIN QUOTIDIEN     93     A
#
#    service_code service_description employee_id  \
# 0             1  ROUTINE INSPECTION   EE0000923
# 1             1  ROUTINE INSPECTION   EE0000633
# 2             1  ROUTINE INSPECTION   EE0000835
# 3             1  ROUTINE INSPECTION   EE0000958
# 4             1  ROUTINE INSPECTION   EE0000629
#
#                  facility_address facility_city facility_id facility_state  \
# 0          3708 N EAGLE ROCK BLVD   LOS ANGELES   FA0170465             CA
# 1             100 WORLD WAY # 120   LOS ANGELES   FA0244690             CA
# ...

# %%
csvHealthViolations.head()
# Out:
#   serial_number        activity_date violation_code  \
# 0     DA08R0TCU  2018-03-30T00:00:00           F030
# 1     DA08R0TCU  2018-03-30T00:00:00           F027
# 2     DA08R0TCU  2018-03-30T00:00:00           F035
# 3     DA08R0TCU  2018-03-30T00:00:00           F033
# 4     DA08R0TCU  2018-03-30T00:00:00           F029
#
#                                violation_description   violation_status  \
# 0  # 30. Food properly stored; food storage conta...  OUT OF COMPLIANCE
# 1                 # 27. Food separated and protected  OUT OF COMPLIANCE
# 2  # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE
# 3  # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# 4  # 29. Toxic substances properly identified, st...  OUT OF COMPLIANCE
#
#    points grade facility_id employee_id   owner_id  score  service_code  \
# 0       1     A   FA0064949   EE0000857  OW0001034     92             1
# ...

# %%
#Reading in the json files
json_file = "jsonFiles/healthInspections.json"
jsonHealthInspections = pd.read_json(json_file, lines = True)
jsonHealthInspections.head()

#Creates two variables containing the locations of each csv
#jsonpath1 = "jsonFiles/healthInspections.json"
#jsonpath2 = "jsonFiles/healthViolations.json"

#Translates the csv files into pandas dataframes
#jsonHealthInspections = pd.read_json(jsonpath1)
#jsonHealthViolations = pd.read_json(jsonpath2)
# Out:
#                            attribution  \
# 0  County of Los Angeles Public Health
#
#                                      attributionLink  averageRating  \
# 0  https://data.lacounty.gov/Health/LOS-ANGELES-C...              0
#
#       category                                            columns   createdAt  \
# 0  A Safe City  [{'dataTypeName': 'text', 'position': 1, 'fiel...  1523312076
#
#                                          description displayType  \
# 0  This dataset contains Environmental Health Ins...       table
#
#    downloadCount                                          flags   ...     \
# 0            344  [default, restorable, restorePossibleForType]   ...
#
#   rowIdentifierColumnId  rowsUpdatedAt  rowsUpdatedBy  \
# 0             353613155     1525280289      nnac-z9x3
#
#                                          tableAuthor   tableId  \
# 0  {'type': 'interactive', 'screenName': 'Adam Sc...  15031310
#
# ...
