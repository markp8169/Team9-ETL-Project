# %%
#Dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()
import requests
import time
import json

# %%
#Reading in the files

#Creates two variables containing the locations of each csv
csvpath = "csvFiles/healthViolations.csv"
csvHealthViolations = pd.read_csv(csvpath)
csvHealthViolations.head()
# Out:
#   serial_number        activity_date facility_name violation_code  \
# 0     DA08R0TCU  2018-03-30T00:00:00   KRUANG TEDD           F030
# 1     DA08R0TCU  2018-03-30T00:00:00   KRUANG TEDD           F027
# 2     DA08R0TCU  2018-03-30T00:00:00   KRUANG TEDD           F035
# 3     DA08R0TCU  2018-03-30T00:00:00   KRUANG TEDD           F033
# 4     DA08R0TCU  2018-03-30T00:00:00   KRUANG TEDD           F029
#
#                                violation_description   violation_status  \
# 0  # 30. Food properly stored; food storage conta...  OUT OF COMPLIANCE
# 1                 # 27. Food separated and protected  OUT OF COMPLIANCE
# 2  # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE
# 3  # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# 4  # 29. Toxic substances properly identified, st...  OUT OF COMPLIANCE
#
#    points grade     facility_address facility_city      ...        \
# 0       1     A  5151 HOLLYWOOD BLVD   LOS ANGELES      ...
# 1       1     A  5151 HOLLYWOOD BLVD   LOS ANGELES      ...
# 2       1     A  5151 HOLLYWOOD BLVD   LOS ANGELES      ...
# 3       1     A  5151 HOLLYWOOD BLVD   LOS ANGELES      ...
# 4       1     A  5151 HOLLYWOOD BLVD   LOS ANGELES      ...
#
#            owner_name                      pe_description program_element_pe  \
# 0  5151 HOLLYWOOD LLC  RESTAURANT (31-60) SEATS HIGH RISK               1635
# 1  5151 HOLLYWOOD LLC  RESTAURANT (31-60) SEATS HIGH RISK               1635
# 2  5151 HOLLYWOOD LLC  RESTAURANT (31-60) SEATS HIGH RISK               1635
# 3  5151 HOLLYWOOD LLC  RESTAURANT (31-60) SEATS HIGH RISK               1635
# 4  5151 HOLLYWOOD LLC  RESTAURANT (31-60) SEATS HIGH RISK               1635
#
#   program_name program_status  record_id score  service_code  \
# 0  KRUANG TEDD         ACTIVE  PR0031205    92             1
# 1  KRUANG TEDD         ACTIVE  PR0031205    92             1
# 2  KRUANG TEDD         ACTIVE  PR0031205    92             1
# 3  KRUANG TEDD         ACTIVE  PR0031205    92             1
# 4  KRUANG TEDD         ACTIVE  PR0031205    92             1
#
#   service_description         row_id
# 0  ROUTINE INSPECTION  DA08R0TCUF030
# 1  ROUTINE INSPECTION  DA08R0TCUF027
# 2  ROUTINE INSPECTION  DA08R0TCUF035
# 3  ROUTINE INSPECTION  DA08R0TCUF033
# 4  ROUTINE INSPECTION  DA08R0TCUF029
#
# [5 rows x 25 columns]

# %%
#csvHealthViolations.dtypes

# %%
csvHealthViolations_cols = ["facility_name", "serial_number", "score", "violation_description"]
healthViolations_transformed= csvHealthViolations[csvHealthViolations_cols].copy()

#healthViolations_transformed = healthViolations_transformed.rename(columns={"facility_name": "Facility_Name",
#                                                                           "facility_id": "ID",
#                                                                           "score": "Score",
#                                                                           "violation_description": "Violation_Description"})
healthViolations_transformed.drop_duplicates("serial_number", inplace=True)
#healthViolations_transformed.set_index("serial_number", inplace=True)

healthViolations_transformed.head()
# Out:
#                  facility_name serial_number  score  \
# 0                  KRUANG TEDD     DA08R0TCU     92
# 7   SPROUTS FARMERS MARKET#403     DA0GBKW3F     97
# 10  LOS ANGELES NEW YORK PIZZA     DA0HEAJNR     92
# 15           THE BAGEL FACTORY     DA0RZDWLN     93
# 22               CREPE EXPRESS     DA0Z5W4J0     92
#
#                                 violation_description
# 0   # 30. Food properly stored; food storage conta...
# 7   # 44. Floors, walls and ceilings: properly bui...
# 10  # 44. Floors, walls and ceilings: properly bui...
# 15  # 29. Toxic substances properly identified, st...
# 22   # 14. Food contact surfaces: clean and sanitized

# %%
#csvHealthViolations_groupby = healthViolations_transformed.groupby(["facility_id", "facility_name", "score", "violation_description"])

#csvHealthViolations_groupby.all()
healthViolations_transformed.dtypes
# Out:
# facility_name            object
# serial_number            object
# score                     int64
# violation_description    object
# dtype: object

# %%
#csvHealthViolations_groupby.to_csv('Health_Violations.csv')

# %%
#read in json
data = json.load(open('jsonFiles/Inspections.json'))

inspections_df = pd.DataFrame(data["data"])
inspections_df.head()
# Out:
#        0                                     1       2           3       4   \
# 0  412181  332032D9-E7BD-4F8D-8C92-58CF5057A994  412181  1541201351  969808
# 1  428600  C78CB01A-453A-4E26-A21A-3FF79F6FBA83  428600  1541201357  969808
# 2  429129  BF888E62-D91E-42AF-BB5B-1B9EBBEEC00B  429129  1541201357  969808
# 3  392634  23EAC538-221D-450C-A2DA-E941E12D840F  392634  1541201336  969808
# 4  392635  945EE22C-428A-416B-8805-CF798AF24CED  392635  1541201336  969808
#
#            5       6     7                    8          9     ...      \
# 0  1541201351  969808  None  2016-06-22T00:00:00  OW0185247    ...
# 1  1541201357  969808  None  2016-09-07T00:00:00  OW0235635    ...
# 2  1541201357  969808  None  2016-09-09T00:00:00  OW0018013    ...
# 3  1541201336  969808  None  2016-04-01T00:00:00  OW0001761    ...
# 4  1541201336  969808  None  2016-04-01T00:00:00  OW0002023    ...
#
#                         18              19  20          21   22  \
# 0         954 E ALOSTA AVE           AZUSA  CA       91702  001
# 1         7275 MELROSE AVE     LOS ANGELES  CA       90046  001
# 2         28788 THE OLD RD        VALENCIA  CA       91355  001
# 3  16550 SOLEDAD CANYON RD  CANYON COUNTRY  CA  91387-3215  001
# 4             2355 PECK RD  SOUTH EL MONTE  CA       91733  001
#
#                    23  24 25         26         27
# 0  ROUTINE INSPECTION  93  A  DAC6YRJ7D  EE0000742
# 1  ROUTINE INSPECTION  90  A  DAKU06F5Y  EE0000951
# 2  ROUTINE INSPECTION  98  A  DAFS03QYK  EE0000735
# 3  ROUTINE INSPECTION  99  A  DAJ8A0PDB  EE0000735
# 4  ROUTINE INSPECTION  92  A  DA6E75RM0  EE0000842
#
# [5 rows x 28 columns]

# %%
rename_inspections_df = inspections_df.rename(columns={26: "serial_number", 11: "facility_id", 23: "service_description"})

rename_inspections_df.head()
# Out:
#         0                                     1       2           3       4  \
# 0  412181  332032D9-E7BD-4F8D-8C92-58CF5057A994  412181  1541201351  969808
# 1  428600  C78CB01A-453A-4E26-A21A-3FF79F6FBA83  428600  1541201357  969808
# 2  429129  BF888E62-D91E-42AF-BB5B-1B9EBBEEC00B  429129  1541201357  969808
# 3  392634  23EAC538-221D-450C-A2DA-E941E12D840F  392634  1541201336  969808
# 4  392635  945EE22C-428A-416B-8805-CF798AF24CED  392635  1541201336  969808
#
#             5       6     7                    8          9    ...      \
# 0  1541201351  969808  None  2016-06-22T00:00:00  OW0185247    ...
# 1  1541201357  969808  None  2016-09-07T00:00:00  OW0235635    ...
# 2  1541201357  969808  None  2016-09-09T00:00:00  OW0018013    ...
# 3  1541201336  969808  None  2016-04-01T00:00:00  OW0001761    ...
# 4  1541201336  969808  None  2016-04-01T00:00:00  OW0002023    ...
#
#                         18              19  20          21   22  \
# 0         954 E ALOSTA AVE           AZUSA  CA       91702  001
# 1         7275 MELROSE AVE     LOS ANGELES  CA       90046  001
# 2         28788 THE OLD RD        VALENCIA  CA       91355  001
# 3  16550 SOLEDAD CANYON RD  CANYON COUNTRY  CA  91387-3215  001
# 4             2355 PECK RD  SOUTH EL MONTE  CA       91733  001
#
#   service_description  24 25 serial_number         27
# 0  ROUTINE INSPECTION  93  A     DAC6YRJ7D  EE0000742
# 1  ROUTINE INSPECTION  90  A     DAKU06F5Y  EE0000951
# 2  ROUTINE INSPECTION  98  A     DAFS03QYK  EE0000735
# 3  ROUTINE INSPECTION  99  A     DAJ8A0PDB  EE0000735
# 4  ROUTINE INSPECTION  92  A     DA6E75RM0  EE0000842
#
# [5 rows x 28 columns]

# %%
new_rename_inspections_df = rename_inspections_df[["facility_id", "serial_number", "service_description"]].copy()

new_rename_inspections_df.drop_duplicates("serial_number", inplace=True)
#new_rename_inspections_df.reset_index(drop=true)

#new_rename_inspections_df = range(len(new_rename_inspections_df.index))

new_rename_inspections_df.head()
# Out:
#   facility_id serial_number service_description
# 0   FA0179753     DAC6YRJ7D  ROUTINE INSPECTION
# 1   FA0239319     DAKU06F5Y  ROUTINE INSPECTION
# 2   FA0071154     DAFS03QYK  ROUTINE INSPECTION
# 3   FA0144494     DAJ8A0PDB  ROUTINE INSPECTION
# 4   FA0005693     DA6E75RM0  ROUTINE INSPECTION

# %%
new_rename_inspections_df.dtypes
# Out:
# facility_id            object
# serial_number          object
# service_description    object
# dtype: object

# %%
#new_rename_inspections_df_groupby = new_rename_inspections_df.groupby(["facility_id", "service_description"])

#new_rename_inspections_df_groupby.all()

# %%
rds_connection_string = "root:Mario#5@127.0.0.1/restaurant_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# C:\Users\JB52612\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
# ['inspections', 'violations']

# %%
healthViolations_transformed.to_sql(name='violations', con=engine, if_exists='replace', index=True)

# %%
new_rename_inspections_df.to_sql(name='inspections',\
                          con=engine, if_exists='replace', index=True)
